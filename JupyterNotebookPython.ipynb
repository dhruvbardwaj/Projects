# %% [markdown]
# # This is a reproduction of the Project I did for STP 429
# ## Project 1

# %%
import pandas as pandas
import numpy as numpy
import scipy as scipy
import sklearn as scikit
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #### Here I've added both Annual dataset and Monthly dataset to Python for analysis.

# %%
annual = pandas.read_csv('annual_mean_data.txt',delim_whitespace=True, header=0)

# %%
monthly = pandas.read_csv('monthly_mean_data.txt',delim_whitespace=True, header=0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-18-b75d49a0b92f> in <module>()
# ----> 1 monthly = pandas.read_csv('monthly_mean_data.txt',delim_whitespace=True, header=0)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
data.head()
# Out:
#    year    mean   unc
# 0  1959  315.97  0.12
# 1  1960  316.91  0.12
# 2  1961  317.64  0.12
# 3  1962  318.45  0.12
# 4  1963  318.99  0.12

# %%
data.columns.values
# Out:
# array(['year', 'mean', 'unc'], dtype=object)

# %%
data[:]
# Out:
#       year     mean      unc
# 0     1959   315.97     0.12
# 1     1960   316.91     0.12
# 2     1961   317.64     0.12
# 3     1962   318.45     0.12
# 4     1963   318.99     0.12
# 5     1964   319.62     0.12
# 6     1965   320.04     0.12
# 7     1966   321.38     0.12
# 8     1967   322.16     0.12
# 9     1968   323.04     0.12
# 10    1969   324.62     0.12
# 11    1970   325.68     0.12
# 12    1971   326.32     0.12
# 13    1972   327.45     0.12
# 14    1973   329.68     0.12
# 15    1974   330.18     0.12
# 16    1975   331.11     0.12
# 17    1976   332.04     0.12
# 18    1977   333.83     0.12
# 19    1978   335.40     0.12
# 20    1979   336.84     0.12
# 21    1980   338.75     0.12
# 22    1981   340.11     0.12
# 23    1982   341.45     0.12
# 24    1983   343.05     0.12
# 25    1984   344.65     0.12
# 26    1985   346.12     0.12
# 27    1986   347.42     0.12
# 28    1987   349.19     0.12
# 29    1988   351.57     0.12
# 30    1989   353.12     0.12
# ...
