# %% [markdown]
# # This is a reproduction of a Project, that I did for STP 429
# ## Project 1

# %% [markdown]
# These are the imported libraries I will be using for this Project

# %%
import pandas as pandas
import numpy as numpy
import scipy as scipy
import sklearn as scikit
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# The data is in the form of a text file. It had several lines with '#' comments in them, that had information about the data, but not the data itself. I tweaked with the read_csv import for a little to found out how to import and found this was the best way.

# %%
annual = pandas.read_csv('annual_mean_data.txt',delim_whitespace=True,comment='#', header=-1, names=['year', 'mean', 'unc', ])
monthly = pandas.read_table('monthly_mean_data.txt',delim_whitespace=True,comment='#', header=0, names=['year','month','decimaldate','average','interpolated','trend','days'])

# %%
monthly.head(15)
# Out:
#     year  month  decimaldate  average  interpolated   trend  days
# 0   1958      3     1958.208   315.71        315.71  314.62    -1
# 1   1958      4     1958.292   317.45        317.45  315.29    -1
# 2   1958      5     1958.375   317.50        317.50  314.71    -1
# 3   1958      6     1958.458   -99.99        317.10  314.85    -1
# 4   1958      7     1958.542   315.86        315.86  314.98    -1
# 5   1958      8     1958.625   314.93        314.93  315.94    -1
# 6   1958      9     1958.708   313.20        313.20  315.91    -1
# 7   1958     10     1958.792   -99.99        312.66  315.61    -1
# 8   1958     11     1958.875   313.33        313.33  315.31    -1
# 9   1958     12     1958.958   314.67        314.67  315.61    -1
# 10  1959      1     1959.042   315.62        315.62  315.70    -1
# 11  1959      2     1959.125   316.38        316.38  315.88    -1
# 12  1959      3     1959.208   316.71        316.71  315.62    -1
# ...

# %%
data.columns.values
# Out:
# array(['year', 'mean', 'unc'], dtype=object)

# %%
data[:]
# Out:
#       year     mean      unc
# 0     1959   315.97     0.12
# 1     1960   316.91     0.12
# 2     1961   317.64     0.12
# 3     1962   318.45     0.12
# 4     1963   318.99     0.12
# 5     1964   319.62     0.12
# 6     1965   320.04     0.12
# 7     1966   321.38     0.12
# 8     1967   322.16     0.12
# 9     1968   323.04     0.12
# 10    1969   324.62     0.12
# 11    1970   325.68     0.12
# 12    1971   326.32     0.12
# 13    1972   327.45     0.12
# 14    1973   329.68     0.12
# 15    1974   330.18     0.12
# 16    1975   331.11     0.12
# 17    1976   332.04     0.12
# 18    1977   333.83     0.12
# 19    1978   335.40     0.12
# 20    1979   336.84     0.12
# 21    1980   338.75     0.12
# 22    1981   340.11     0.12
# 23    1982   341.45     0.12
# 24    1983   343.05     0.12
# 25    1984   344.65     0.12
# 26    1985   346.12     0.12
# 27    1986   347.42     0.12
# 28    1987   349.19     0.12
# 29    1988   351.57     0.12
# 30    1989   353.12     0.12
# ...
